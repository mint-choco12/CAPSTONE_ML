# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Gathering Data

# %%
#Dataset Skincare
dataset = 'https://raw.githubusercontent.com/mint-choco12/CAPSTONE_ML/main/Dataset.csv'
dataset_df = pd.read_csv(dataset)
dataset_df.head()
# Out:
#    Unnamed: 0                          product_name     brand     Category  \
# 0           0                 Cica Night Cream 15gr     NPURE  Moisturizer
# 1           1  Hydra U Cooling and Moisturizing Gel  SUGARPOT  Moisturizer
# 2           2                         Soothing Mist  SUGARPOT    Face Mist
# 3           3                   Cica Day Cream 15gr     NPURE  Moisturizer
# 4           4               Acneact Anti Acne Serum      ERHA        Serum
#
#      Dry  Sensitive  Oily  Semua Tipe Kulit  Acne Free  Anti-aging  ...  \
# 0   True       True  True             False       True       False  ...
# 1   True       True  True             False       True       False  ...
# 2   True       True  True             False      False       False  ...
# 3   True       True  True             False       True       False  ...
# 4  False       True  True             False       True       False  ...
#
#     Cica  Salicylic Acid  Niacinamide  Ceramide  allantoin  Glycol  Retinol  \
# ...

# %%
#Kuisioner
questions = 'https://raw.githubusercontent.com/mint-choco12/CAPSTONE_ML/main/SurveyQuestion.csv'
questions_df = pd.read_csv(questions)
questions_df.head()
# Out:
#                                           Pertanyaan  \
# 0  Bagaimana kulit wajah Anda terasa setelah menc...
# 1               Bagaimana penampilan pori-pori Anda?
# 2            Seberapa sering Anda mengalami jerawat?
# 3          Bagaimana kulit Anda terasa di sore hari?
# 4  Apakah kulit Anda sering mengalami kemerahan a...
#
#                                                A  \
# 0                            Kering dan tertarik
# 1                          Hampir tidak terlihat
# 2                                  Jarang sekali
# 3                                  Sangat kering
# 4  Sering, terutama saat udara dingin atau panas
#
#                                         B  \
# 0                               Berminyak
# 1         Terlihat besar di beberapa area
# 2              Sering, terutama di zona T
# 3              Berminyak di seluruh wajah
# 4  Kadang-kadang saat mencoba produk baru
#
#                                               C  \
# ...

# %%
#Syarat
choice = 'https://raw.githubusercontent.com/mint-choco12/CAPSTONE_ML/main/MultipleChoice.csv'
choice_df = pd.read_csv(choice)
choice_df.head()
# Out:
#                                           Pertanyaan               1       2  \
# 0  Apakah anda memiliki alergi terhadap bahan ber...  Salicylic Acid  Glycol
#
#          3      0
# 0  Retinol  Tidak

# %% [markdown]
# # Assessing Data

# %%
dataset_df.info()
questions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        928 non-null    int64
#  1   product_name      928 non-null    object
#  2   brand             928 non-null    object
#  3   Category          928 non-null    object
#  4   Dry               928 non-null    bool
#  5   Sensitive         928 non-null    bool
#  6   Oily              928 non-null    bool
#  7   Semua Tipe Kulit  928 non-null    bool
#  8   Acne Free         928 non-null    bool
#  9   Anti-aging        928 non-null    bool
#  10  Brightening       928 non-null    bool
#  11  Pore Care         928 non-null    bool
#  12  UV Protection     928 non-null    bool
#  13  Water             928 non-null    bool
#  14  Cica              928 non-null    bool
#  15  Salicylic Acid    928 non-null    bool
#  16  Niacinamide       928 non-null    bool
# ...

# %%
# Memeriksa missing value
dataset_df.isna().sum
questions_df.isna().sum
# Out:
# <bound method DataFrame.sum of     Pertanyaan      A      B      C      D
# 0        False  False  False  False  False
# 1        False  False  False  False  False
# 2        False  False  False  False  False
# 3        False  False  False  False  False
# 4        False  False  False  False  False
# 5        False  False  False  False  False
# 6        False  False  False  False  False
# 7        False  False  False  False  False
# 8        False  False  False  False  False
# 9        False  False  False  False  False
# 10       False  False  False  False  False
# 11       False  False  False  False  False
# 12       False  False  False  False  False
# 13       False  False  False  False  False>

# %%
# Memeriksa duplikasi
print("Jumlah duplikasi: ", dataset_df.duplicated().sum())
print("Jumlah duplikasi: ", questions_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0
# Jumlah duplikasi:  0

# %% [markdown]
# # Cleaning data

# %%
# Menghapus kolom unnamed:0
dataset_df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
# Menghapus duplikat pada dataset_df
dataset_df = dataset_df.drop_duplicates()
print("Jumlah duplikasi:", dataset_df.duplicated().sum())i
# Out:
# Jumlah duplikasi: 0

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 927 entries, 0 to 927
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_name      927 non-null    object
#  1   brand             927 non-null    object
#  2   Category          927 non-null    object
#  3   Dry               927 non-null    bool
#  4   Sensitive         927 non-null    bool
#  5   Oily              927 non-null    bool
#  6   Semua Tipe Kulit  927 non-null    bool
#  7   Acne Free         927 non-null    bool
#  8   Anti-aging        927 non-null    bool
#  9   Brightening       927 non-null    bool
#  10  Pore Care         927 non-null    bool
#  11  UV Protection     927 non-null    bool
#  12  Water             927 non-null    bool
#  13  Cica              927 non-null    bool
#  14  Salicylic Acid    927 non-null    bool
#  15  Niacinamide       927 non-null    bool
#  16  Ceramide          927 non-null    bool
# ...

# %% [markdown]
# ###Klasifikasi User

# %%
#Dataset Jawaban Pengguna : Kuisioner
an_que = 'https://raw.githubusercontent.com/mint-choco12/CAPSTONE_ML/main/answered_questions.csv'
an_que_df = pd.read_csv(an_que)
an_que_df.head()
# Out:
#                 Nama  Pertanyaan_1  Pertanyaan_2  Pertanyaan_3  Pertanyaan_4  \
# 0  John Anderson DDS             3             4             4             3
# 1         Lisa White             2             4             4             4
# 2  Brandon Weeks DDS             2             4             3             4
# 3    Heather Simpson             3             3             3             4
# 4        Jason Gomez             2             3             1             2
#
#    Pertanyaan_5  Pertanyaan_6  Pertanyaan_7  Pertanyaan_8  Pertanyaan_9  \
# 0             1             3             4             2             4
# 1             3             2             2             1             4
# 2             4             3             3             3             2
# 3             2             3             2             2             1
# 4             4             4             3             1             3
#
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# Tentukan kolom pilihan
choice_columns = ['A', 'B', 'C', 'D']

# Isi kolom dengan nilai tetap
questions_df[choice_columns] = [[1, 2, 3, 4]] * len(questions_df)

# Tampilkan hasil
print(questions_df.head())
# Out:
#                                           Pertanyaan  A  B  C  D
# 0  Bagaimana kulit wajah Anda terasa setelah menc...  1  2  3  4
# 1               Bagaimana penampilan pori-pori Anda?  1  2  3  4
# 2            Seberapa sering Anda mengalami jerawat?  1  2  3  4
# 3          Bagaimana kulit Anda terasa di sore hari?  1  2  3  4
# 4  Apakah kulit Anda sering mengalami kemerahan a...  1  2  3  4

# %% [markdown]
# # Pembobotan pada Multiple Choice
